# %%
print("Planet Weights!")

#-----------------------------

Weight = float(input("Quanto pesa la tua terra? "))
Planet = int(input("Numero del pianeta (1-7): "))

D_W = ()

if Planet == 1:
  D_W = Weight * 0.38
elif Planet == 2:
  D_W = Weight * 0.91
elif Planet == 3:
  D_W = Weight * 0.38
elif Planet == 4:
  D_W = Weight * 2.53
elif Planet == 5:
  D_W = Weight * 1.07
elif Planet == 6:
  D_W = Weight * 0.89
elif Planet == 7:
  D_W = Weight * 1.14
else:
  print('Invalid planet number')

print(D_W)
# Out:
# Planet Weights!
# 9236.6466
