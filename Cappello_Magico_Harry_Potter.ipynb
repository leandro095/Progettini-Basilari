# %%
# Write code below 💖
import time
print("------")
print('è il momento del Cappello magico')
time.sleep(2)
print('Rispondi alle domande per scoprire in quale casa di Hogwarts verresti smistato!')
time.sleep(2)
print('Rispondi con il numero corrispondente alla tua scelta')
time.sleep(2)
print('e mi raccomando, rispondi onestamente!')
time.sleep(2)
print('---------------------------------------------------')

Grifondoro = 0
Corvonero = 0
Tassorosso = 0
Serpeverde = 0

print('Preferisci luce o oscurità?')
print('1) Luce')
print('2) Oscurità')

Q1 = int(input('Rispondi scegliendo il numero della tua risposta (1 o 2): '))

if Q1 == 1:
  Grifondoro = Grifondoro +1
  Corvonero = Corvonero +1
elif Q1 == 2:
  Tassorosso = Tassorosso +1
  Serpeverde = Serpeverde +1
else:
  print('Input errato')

print('---------------------------------------------------')

print('Quando morirai, vuoi che le persone ti ricordino come:')
print('1) Una persona buona')
print('2) Il/la Grande')
print('3) Il/la Saggio/a')
print('4) Il/la Coraggioso/a')

Q2 = int(input('La tua risposta è? (1, 2, 3, 4): '))

if Q2 == 1:
  Tassorosso = Tassorosso +2
elif Q2 == 2:
  Serpeverde = Serpeverde +2
elif Q2 == 3:
  Corvonero = Corvonero +2
elif Q2 == 4:
  Grifondoro = Grifondoro +2
else:
  print('Wrong input')

print('---------------------------------------------------')

print('Quale di questi strumenti preferisci ascoltare?')
print('1) Il violino')
print('2) La tromba')
print('3) Il pianoforte')
print('4) Il tamburo')

Q3 = int(input('Dimmi la tua risposta (1, 2, 3, 4): '))

if Q3 == 1:
  Serpeverde = Serpeverde +4
elif Q3 == 2:
  Tassorosso = Tassorosso +4
elif Q3 == 3:
  Corvonero = Corvonero +4
elif Q3 == 4:
  Grifondoro = Grifondoro +4
else:
  print('Wrong input')

print('---------------------------------------------------')

print('Di fronte a un pericolo, cosa fai per prima cosa:')
print('1) Ti lanci subito in avanti')
print('2) Analizzi bene la situazione')
print('3) Cerchi di proteggere gli altri')
print('4) Valuti come potresti trarne vantaggio')

Q3 = int(input('Dimmi la tua risposta (1, 2, 3, 4): '))

if Q3 == 4:
  Serpeverde = Serpeverde +4
elif Q3 == 3:
  Tassorosso = Tassorosso +4
elif Q3 == 2:
  Corvonero = Corvonero +4
elif Q3 == 1:
  Grifondoro = Grifondoro +4
else:
  print('Wrong input')

print('---------------------------------------------------')

print('Quale luogo ti attira di più a Hogwarts:')
print('1) la Sala Comune vicino al fuoco')
print('2) la Biblioteca')
print('3) il Campo da Quidditch')
print('4) le Segrete del castello')

Q3 = int(input('Dimmi la tua risposta (1, 2, 3, 4): '))

if Q3 == 4:
  Serpeverde = Serpeverde +4
elif Q3 == 1:
  Tassorosso = Tassorosso +4
elif Q3 == 2:
  Corvonero = Corvonero +4
elif Q3 == 3:
  Grifondoro = Grifondoro +4
else:
  print('Wrong input')

print('---------------------------------------------------')

time.sleep(1)

print("bene, adesso scopriamo la tua casa...")
time.sleep(3)

if Grifondoro >= Serpeverde and Grifondoro >= Tassorosso and Grifondoro >= Corvonero:
  print("SEI UN GRIFONDOROOOOOO!")
elif Corvonero >= Serpeverde and Corvonero >= Tassorosso:
  print("SEI UN RAVENCLAWWWWWWW!")
elif Tassorosso >= Serpeverde:
  print("SEI UN TASSOROSSOOOOO!")
else:
  print("SERPEVERDEE.......")
